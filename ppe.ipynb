# %% [markdown]
# Accessing data from Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Defining the root directory

# %%
ROOT_DIR = '/content/gdrive/My Drive/PersonalProtectionDetection'

# %% [markdown]
# Installing Ultralytics

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.4/778.4 kB 8.7 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %% [markdown]
# Train the Model

# %%
import os
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
results = model.train(data=os.path.join(ROOT_DIR, "google_colab_config.yaml"), epochs=20)
# Out:
# Ultralytics YOLOv8.2.22 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Result

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import locale

# %%
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/PersonalProtectionDetection'

# %%
# !yolo task=detect mode=predict model='/content/gdrive/My Drive/PersonalProtectionDetection/runs/detect/train4/weights/best.pt' conf=0.55 source='/content/gdrive/My Drive/PersonalProtectionDetection/Video'
# Out:
# Ultralytics YOLOv8.2.22 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3007013 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/1260) /content/gdrive/My Drive/PersonalProtectionDetection/Video/videoplayback.mp4: 384x640 (no detections), 82.6ms
# video 1/1 (frame 2/1260) /content/gdrive/My Drive/PersonalProtectionDetection/Video/videoplayback.mp4: 384x640 (no detections), 6.6ms
# video 1/1 (frame 3/1260) /content/gdrive/My Drive/PersonalProtectionDetection/Video/videoplayback.mp4: 384x640 (no detections), 5.9ms
# video 1/1 (frame 4/1260) /content/gdrive/My Drive/PersonalProtectionDetection/Video/videoplayback.mp4: 384x640 (no detections), 5.8ms
# video 1/1 (frame 5/1260) /content/gdrive/My Drive/PersonalProtectionDetection/Video/videoplayback.mp4: 384x640 (no detections), 6.2ms
# video 1/1 (frame 6/1260) /content/gdrive/My Drive/PersonalProtectionDetection/Video/videoplayback.mp4: 384x640 (no detections), 6.2ms
# ...

# %%
# !cp -r '/content/runs/detect/predict' '/content/gdrive/My Drive/PersonalProtectionDetection/Output'
